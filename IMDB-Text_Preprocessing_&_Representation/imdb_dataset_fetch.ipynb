# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
pd.DataFrame(response.json()['results'])[['title','overview','genre_ids']]
# Out:
#                                             title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# 5                                   Spirited Away
# 6                                 The Dark Knight
# 7                     Dilwale Dulhania Le Jayenge
# 8                                  The Green Mile
# 9                                        Parasite
# 10  The Lord of the Rings: The Return of the King
# 11                                   Pulp Fiction
# 12                                     Your Name.
# 13                 The Good, the Bad and the Ugly
# 14                                   Interstellar
# 15                                   Forrest Gump
# 16                                  Seven Samurai
# 17                                     GoodFellas
# ...

# %%
df =  pd.DataFrame()

# %%
from tqdm import tqdm
import os
import time

API_KEY = os.getenv("TMDB_API_KEY")
dfs = []

for page in tqdm(range(1, 501), desc="Fetching pages"):
    try:
        response = requests.get(
            "https://api.themoviedb.org/3/movie/top_rated",
            params={
                "api_key": "8265bd1679663a7ea12ac168da84d2e8",
                "language": "en-US",
                "page": page
            },
            timeout=10
        )

        if response.status_code != 200:
            tqdm.write(f"⚠️ Status {response.status_code} on page {page}")
            time.sleep(2)
            continue

        temp_df = pd.DataFrame(response.json()["results"])[
            ["title", "overview", "genre_ids"]
        ]
        dfs.append(temp_df)

        time.sleep(0.3)  # 👈 CRITICAL

    except requests.exceptions.RequestException as e:
        tqdm.write(f"❌ Error on page {page}: {e}")
        time.sleep(5)
        continue

df = pd.concat(dfs, ignore_index=True)
# Out:
# Fetching pages:   0%|          | 1/500 [00:01<08:18,  1.00it/s]
# ❌ Error on page 2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Fetching pages:   1%|          | 4/500 [00:09<15:50,  1.92s/it]
# ❌ Error on page 5: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Fetching pages:   1%|          | 5/500 [00:14<26:16,  3.18s/it]
# ❌ Error on page 6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Fetching pages:   1%|          | 6/500 [00:19<31:53,  3.87s/it]
# ❌ Error on page 7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Fetching pages:   2%|▏         | 10/500 [00:28<17:46,  2.18s/it]
# ❌ Error on page 11: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Fetching pages:   2%|▏         | 11/500 [00:33<25:38,  3.15s/it]
# ❌ Error on page 12: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ...
